# %% [markdown]
# # Microsoft Stock Time Series Analysis
#
# This report analyzes Microsoft stock prices and evaluates several forecasting models.

# %%
library(here)

msft_ts <- readRDS(
  here("data", "processed", "msft_ts.rds")
)

# %%
summary(msft_ts)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   40.29   57.85   93.86  107.42  138.97  244.99
